# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.datasets import fetch_20newsgroups
from sklearn.utils import shuffle
import re
from wordcloud import WordCloud

from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud

from sklearn.decomposition import LatentDirichletAllocation as LDA
from tensor_lda.tensor_lda import TensorLDA
from time import time
import umap.umap_ as umap

# %%
# select a sample from the original dataset
n_samples = 5000
n_features = 1000
n_components = 20
n_top_words = 10

# %%
dataset = fetch_20newsgroups(shuffle=True, random_state=2,
                             remove=('headers', 'footers', 'quotes'))
data_samples = dataset.data[:n_samples]

# %%
# stop words
global stopwords_list
stopwords_list = set(stopwords.words('english'))

# %%
global lemma 
lemma = WordNetLemmatizer()

# %%
def text_clean(news):
    # Tokenize
    word_list = word_tokenize(news)
    
    clean_word_list = []
    for word in word_list:
        if len(word) > 2 and word not in stopwords_list:
            clean_word_list.append(lemma.lemmatize(word))
    # list to sentence
    sentence = ' '.join(clean_word_list)
    
    return sentence

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# preview of training data
news_df = pd.DataFrame({'News': dataset.data[:n_samples],
                        'Target': dataset.target[:n_samples]})
news_df = news_df.iloc[:n_samples, :]
news_df.head()
# Out:
#                                                 News  Target
# 0  Something about how Koresh had threatened to c...      16
# 1  I have an Okidata 2410 printer for which I wou...       2
# 2  \nI just put replaced the motherboard in a sys...       3
# 3  From article <1rc07h$ern@olivea.ATC.Olivetti.C...       2
# 4  \nThis is similar to my saying that Clinton's ...      18

# %%
# size of the entire dataset
news_df.shape
# Out:
# (5000, 2)

# %%
# getting the target name into the dataset
news_df['Target_name'] = news_df['Target'].apply(lambda x: dataset.target_names[x])
news_df.head()
# Out:
#                                                 News  Target
# 0  Something about how Koresh had threatened to c...      16  \
# 1  I have an Okidata 2410 printer for which I wou...       2
# 2  \nI just put replaced the motherboard in a sys...       3
# 3  From article <1rc07h$ern@olivea.ATC.Olivetti.C...       2
# 4  \nThis is similar to my saying that Clinton's ...      18
#
#                 Target_name
# 0        talk.politics.guns
# 1   comp.os.ms-windows.misc
# 2  comp.sys.ibm.pc.hardware
# 3   comp.os.ms-windows.misc
# 4        talk.politics.misc

# %%
# plot the distribution of news topics
fig = plt.figure(figsize=[10,15])
ax = sns.countplot(y=news_df['Target_name'], palette='mako', order=news_df['Target_name'].value_counts().index)
plt.title('Distribution of Topics')
plt.ylabel('Topics')
plt.xlabel('Count of News Articles')
# Out:
# Text(0.5, 0, 'Count of News Articles')

# %%
# any null value in the table
news_df.isna().sum()
# Out:
# News           0
# Target         0
# Target_name    0
# dtype: int64

# %% [markdown]
# * The full dataset is consisted of 18846 news articles.
# * The dataset has no null values
# * There are a total of 20 topics in this dataset.

# %%
# getting only the text data
pattern = re.compile(r'[^A-Za-z]+')
text_data = news_df['News'].str.replace(pattern, ' ', regex=True).str.strip()
text_data.head()
# Out:
# 0    Something about how Koresh had threatened to c...
# 1    I have an Okidata printer for which I would li...
# 2    I just put replaced the motherboard in a syste...
# 3    From article rc h ern olivea ATC Olivetti Com ...
# 4    This is similar to my saying that Clinton s ti...
# Name: News, dtype: object

# %%
# using the function text_clean to get the meaningful words
processed_text_data = text_data.apply(lambda x: text_clean(x))
processed_text_data.head()
# Out:
# 0    Something Koresh threatened cause local proble...
# 1    Okidata printer would like printer driver Has ...
# 2    put replaced motherboard system similar questi...
# 3    From article ern olivea ATC Olivetti Com manu ...
# 4    This similar saying Clinton timber summit litt...
# Name: News, dtype: object

# %%
# plot word count for news text
wordcloud = WordCloud(background_color='white',
                      max_words=200).generate(str(processed_text_data))
fig = plt.figure(figsize=[15,15])
plt.title('WordCloud of News')
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
# the length of the news description
description_len = news_df['News'].str.len()
description_len.describe()
# Out:
# count     5000.000000
# mean      1223.320000
# std       4050.301153
# min          0.000000
# 25%        241.000000
# 50%        501.000000
# 75%        979.000000
# max      72161.000000
# Name: News, dtype: float64

# %%
tf_vectorizer = CountVectorizer(max_df=0.8, min_df=5,
                                max_features=n_features,
                                stop_words='english')

tf = tf_vectorizer.fit_transform(text_data)

# %%
def plot_top_words(model, feature_names, n_top_words, title):
    fig, axes = plt.subplots(4, 5, figsize=(30, 30), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[-n_top_words:]
        top_features = feature_names[top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f"Topic {topic_idx +1}", fontdict={"fontsize": 30})
        ax.tick_params(axis="both", which="major", labelsize=20)
        for i in "top right left".split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()
    
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        topic_prior = model.alpha_[topic_idx]
        message = "Topic #%d (prior: %.3f): " % (topic_idx, topic_prior)
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# %%
t0 = time()
lda_normal = LDA(n_components=20)
lda_normal.fit(tf)
print("done in %0.3fs." % (time() - t0))
print()
# Out:
# done in 14.243s.

# %%
embedding = umap.UMAP(n_neighbors=150, min_dist=0.5, random_state=12).fit_transform(lda_normal.transform(tf)) 
plt.figure(figsize=(12,6)) 
plt.scatter(embedding[:, 0], embedding[:, 1], 
c = news_df['Target'].values, 
s = 10, # size 
edgecolor='none' ) 
plt.show()
# Out:
# /home/zhishang/anaconda3/lib/python3.8/site-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
tf_feature_names = np.array(tf_vectorizer.get_feature_names())

# %%
plot_top_words(lda_normal, tf_feature_names, 10, "Topics in LDA model")

# %%
t0 = time()
lda_tensor = TensorLDA(n_components=20, alpha0=.1)
lda_tensor.fit(tf)
print("done in %0.3fs." % (time() - t0))
print()
# Out:
# done in 9.176s.

# %%
embedding = umap.UMAP(n_neighbors=150, min_dist=0.5, random_state=12).fit_transform(lda_tensor.transform(tf)) 
plt.figure(figsize=(12,6)) 
plt.scatter(embedding[:, 0], embedding[:, 1], 
c = news_df['Target'].values, 
s = 10, # size 
edgecolor='none' ) 
plt.show()
# Out:
# /home/zhishang/anaconda3/lib/python3.8/site-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
tf_feature_names = np.array(tf_vectorizer.get_feature_names())

# %%
plot_top_words(lda_tensor, tf_feature_names, 10, "Topics in LDA+Tensor Decomp model")
